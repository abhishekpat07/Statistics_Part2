# %% [markdown]
# #1. What is hypothesis testing in statistics?
# - Hypothesis testing is a type of statisical analysis in which you put your assumptions about a population parameter to the test. It is used to estimate the relationship between two statistical variables.

# %% [markdown]
# #2.  What is the null hypothesis, and how does it differ from the alternative hypothesis?
# - The null hypothesis of a test always predicts no effect or no relationship between variables, while the alternative hypothesis states your research prediction of an effect or relationship.

# %% [markdown]
# #3.  What is the significance level in hypothesis testing, and why is it important?
# - The significance level is the probabilty of rejecting the null hypothesis when it the null hypothesis is true and is denoted by α .

# %% [markdown]
# #4. What does a P-value represent in hypothesis testing?
# - A P-value is statistical measurment used to validate a hypothesis against observed data.

# %% [markdown]
# #5. How do you interpret the P-value in hypothesis testing?
# - A P-value in hypothesis testing represents the probability of observing data as extreme as, or more extreme than, what was actually observed, assuming the null hypothesis is true.

# %% [markdown]
# #6. What are Type 1 and Type 2 errors in hypothesis testing?
# - In Statistics, a Type 1 error is false positive conclusion, while a Type II error is a false negativev conclusion.

# %% [markdown]
# #7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# - One-tailed tests allow for the possibility of an effect in one direction. Two-tailed test for the possibilty of an effect in two direction- positive and negative.

# %% [markdown]
# #8. What is the Z-test, and when is it used in hypothesis testing?
# - A z-test is a statistical test used to determine whether two population means are different when the variances are known and the sample size is large.

# %% [markdown]
# #9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
# - A Z-score is calculated by subtracting the population mean from a data point and then dividing the result by the population standard deviation.

# %% [markdown]
# #10. What is the T-distribution, and when should it be used instead of the normal distribution?
# - The t-distribution describes the standardized distances of sample means to the population mean when the population standard deviation is not known, and the observations come from a normally distributed population. When working problems when the population standard deviation is not known and the sample size is small(n<30).

# %% [markdown]
# #11.  What is the difference between a Z-test and a T-test?
# - A Z-test is used in statistics when the population standard deviation is known and typically applies to large sample sizes, while a T-test is used when the population standard deviation is unknown and is more suitable for small sample sizes.

# %% [markdown]
# #12. What is the T-test, and how is it used in hypothesis testing?
# - A t-test is an inferential statistic used to determine if there is a significant difference between the means of two groups and how they are related.

# %% [markdown]
# #13. What is the relationship between Z-test and T-test in hypothesis testing?
# - z-tests are used when we have large sample sizes (n > 30), whereas t-tests are most helpful with a smaller sample size (n < 30).

# %% [markdown]
# #14. What is a confidence interval, and how is it used to interpret statistical results?
# - confidence interval shows the probability that a parameter will fall between a pair of values around the mean.If the confidence interval does not enclose the value reflecting 'no effect', this represents a difference that is statistically significant.

# %% [markdown]
# #15. What is the margin of error, and how does it affect the confidence interval?
# - Margin of error is a statistical term that represents the range of uncertainty or variability around an estimate or measurement.

# %% [markdown]
# #16.  How is Bayes' Theorem used in statistics, and what is its significance?
# - Bayes' Theorem thus gives the probability of an event based on new information that is or may be related to that event.

# %% [markdown]
# #17. What is the Chi-square distribution, and when is it used?
# - A Chi-square distribution is a statistical distribution used primarily for hypothesis testing, particularly when analyzing categorical data, to determine if there is a significant difference between observed frequencies and expected frequencies in a dataset.

# %% [markdown]
# #18. What is the Chi-square goodness of fit test, and how is it applied?
# - The Chi-square goodness of fit test is a statistical hypothesis test used to determine whether a variable is likely to come from a specified distribution or not.

# %% [markdown]
# #19. What is the F-distribution, and when is it used in hypothesis testing?
# - The F-distribution is a continuous probability distribution used in statistics primarily to compare the variances of two populations.

# %% [markdown]
# #20. What is an ANOVA test, and what are its assumptions?
# - Analysis of Variance (ANOVA) is a statistical procedure that separates variation into components and tests hypotheses.

# %% [markdown]
# #21. What are the different types of ANOVA tests?
# - There are two types of ANOVA that are commonly used, the one-way ANOVA and the two-way ANOVA.

# %% [markdown]
# #22. What is the F-test, and how does it relate to hypothesis testing?
# - F test is a statistical test that is used in hypothesis testing to check whether the variances of two populations or two samples are equal or not.

# %% [markdown]
# #Practical

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

import numpy as np
from scipy.stats import norm

def z_test(sample, population_mean, population_std, alpha=0.05, alternative='two-sided'):

    sample_size = len(sample)
    sample_mean = np.mean(sample)

    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    if alternative == 'two-sided':
        p_value = 2 * (1 - norm.cdf(abs(z_score)))
    elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_score)
    elif alternative == 'less':
        p_value = norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose from 'two-sided', 'greater', or 'less'.")

    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "Z-score": z_score,
        "p-value": p_value,
        "Decision": interpretation
    }

sample_data = [52, 55, 53, 58, 54, 56, 57, 50, 51, 53]
population_mean = 50
population_std = 5
alpha = 0.05
alternative = 'two-sided'

result = z_test(sample_data, population_mean, population_std, alpha, alternative)
print(result)
# Out:
# {'Z-score': 2.4665765749313353, 'p-value': 0.013641155794968496, 'Decision': 'Reject the null hypothesis'}

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

import numpy as np
from scipy.stats import norm

def z_test(sample, population_mean, population_std, alpha=0.05, alternative='two-sided'):

    sample_size = len(sample)
    sample_mean = np.mean(sample)

        z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

        if alternative == 'two-sided':
        p_value = 2 * (1 - norm.cdf(abs(z_score)))
    elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_score)
    elif alternative == 'less':
        p_value = norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose from 'two-sided', 'greater', or 'less'.")

       interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "Z-score": z_score,
        "p-value": p_value,
        "Decision": interpretation
    }

np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=5, size=30)
population_mean = 50
population_std = 5
alpha = 0.05
alternative = 'two-sided'

result = z_test(sample_data, population_mean, population_std, alpha, alternative)
print(result)
# Out:
# {'Z-score': -1.0305229898218877, 'p-value': 0.3027645658813305, 'Decision': 'Fail to reject the null hypothesis'}

# %%
#3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05, alternative='two-sided'):

    sample_size = len(sample)
    sample_mean = np.mean(sample)


    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

        if alternative == 'two-sided':
        p_value = 2 * (1 - norm.cdf(abs(z_score)))
    elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_score)
    elif alternative == 'less':
        p_value = norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose from 'two-sided', 'greater', or 'less'.")

        interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "Z-score": z_score,
        "p-value": p_value,
        "Decision": interpretation
    }

np.random.seed(42)
sample_data = np.random.normal(loc=52, scale=5, size=30)
population_mean = 50
population_std = 5
alpha = 0.05
alternative = 'two-sided'

result = one_sample_z_test(sample_data, population_mean, population_std, alpha, alternative)
print(result)
# Out:
# {'Z-score': 1.1603672401987766, 'p-value': 0.24589931875480842, 'Decision': 'Fail to reject the null hypothesis'}

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05, alternative='two-sided'):

    sample_size = len(sample)
    sample_mean = np.mean(sample)


    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))


    if alternative == 'two-sided':
        p_value = 2 * (1 - norm.cdf(abs(z_score)))
    elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_score)
    elif alternative == 'less':
        p_value = norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose from 'two-sided', 'greater', or 'less'.")


    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "Z-score": z_score,
        "p-value": p_value,
        "Decision": interpretation
    }

np.random.seed(42)
sample_data = np.random.normal(loc=52, scale=5, size=30)
population_mean = 50
population_std = 5
alpha = 0.05
alternative = 'two-sided'

result = one_sample_z_test(sample_data, population_mean, population_std, alpha, alternative)
print(result)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)
critical_value = norm.ppf(1 - alpha / 2)

plt.figure(figsize=(10, 5))
plt.plot(x, y, label="Standard Normal Distribution")
plt.axvline(-critical_value, color='red', linestyle='dashed', label=f'Critical Region (-{critical_value:.2f})')
plt.axvline(critical_value, color='red', linestyle='dashed', label=f'Critical Region ({critical_value:.2f})')
plt.axvline(result["Z-score"], color='blue', linestyle='solid', label=f'Z-score ({result["Z-score"]:.2f})')
plt.fill_between(x, y, where=(x < -critical_value) | (x > critical_value), color='red', alpha=0.3)
plt.title("Two-Tailed Z-Test Decision Region")
plt.legend()
plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.show()
# Out:
# {'Z-score': 1.1603672401987766, 'p-value': 0.24589931875480842, 'Decision': 'Fail to reject the null hypothesis'}

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05, alternative='two-sided'):

    sample_size = len(sample)
    sample_mean = np.mean(sample)

    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    if alternative == 'two-sided':
        p_value = 2 * (1 - norm.cdf(abs(z_score)))
    elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_score)
    elif alternative == 'less':
        p_value = norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose from 'two-sided', 'greater', or 'less'.")

    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "Z-score": z_score,
        "p-value": p_value,
        "Decision": interpretation
    }

def visualize_errors(alpha=0.05, beta=0.2):

    x = np.linspace(-4, 4, 1000)
    null_dist = norm.pdf(x, 0, 1)
    alt_dist = norm.pdf(x, 2, 1)

    critical_value = norm.ppf(1 - alpha)

    plt.figure(figsize=(10, 5))
    plt.plot(x, null_dist, label="Null Distribution (H0)", color='blue')
    plt.plot(x, alt_dist, label="Alternative Distribution (H1)", color='green')

    plt.fill_between(x, null_dist, where=(x > critical_value), color='red', alpha=0.3, label="Type 1 Error (α)")
    plt.fill_between(x, alt_dist, where=(x < critical_value), color='orange', alpha=0.3, label="Type 2 Error (β)")

    plt.axvline(critical_value, color='black', linestyle='dashed', label=f'Critical Value ({critical_value:.2f})')
    plt.title("Type 1 and Type 2 Errors in Hypothesis Testing")
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.show()

np.random.seed(42)
sample_data = np.random.normal(loc=52, scale=5, size=30)
population_mean = 50
population_std = 5
alpha = 0.05
alternative = 'two-sided'

result = one_sample_z_test(sample_data, population_mean, population_std, alpha, alternative)
print(result)

visualize_errors(alpha=0.05, beta=0.2)
# Out:
# {'Z-score': 1.1603672401987766, 'p-value': 0.24589931875480842, 'Decision': 'Fail to reject the null hypothesis'}

# %%
#6. Write a Python program to perform an independent T-test and interpret the results.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

def independent_t_test(sample1, sample2, alpha=0.05, equal_var=True):

    t_stat, p_value = ttest_ind(sample1, sample2, equal_var=equal_var)

    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "T-statistic": t_stat,
        "p-value": p_value,
        "Decision": interpretation
    }

def visualize_t_test(sample1, sample2):

    plt.figure(figsize=(10, 5))
    plt.hist(sample1, bins=15, alpha=0.5, label="Sample 1", color='blue', density=True)
    plt.hist(sample2, bins=15, alpha=0.5, label="Sample 2", color='green', density=True)
    plt.axvline(np.mean(sample1), color='blue', linestyle='dashed', linewidth=2, label=f'Mean Sample 1 ({np.mean(sample1):.2f})')
    plt.axvline(np.mean(sample2), color='green', linestyle='dashed', linewidth=2, label=f'Mean Sample 2 ({np.mean(sample2):.2f})')
    plt.title("Distribution of Two Samples")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.show()


np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=5, size=30)
sample2 = np.random.normal(loc=53, scale=5, size=30)

alpha = 0.05

test_result = independent_t_test(sample1, sample2, alpha)
print(test_result)

visualize_t_test(sample1, sample2)
# Out:
# {'T-statistic': -2.821074768517716, 'p-value': 0.006542565964576734, 'Decision': 'Reject the null hypothesis'}

# %%
#7. Perform a paired sample T-test using Python and visualize the comparison results.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

def paired_t_test(before, after, alpha=0.05):

    t_stat, p_value = ttest_rel(before, after)

    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

    return {
        "T-statistic": t_stat,
        "p-value": p_value,
        "Decision": interpretation
    }

def visualize_paired_t_test(before, after):

    plt.figure(figsize=(8, 5))
    plt.plot(before, after, 'bo', label="Paired Samples")
    plt.plot([min(before), max(before)], [min(before), max(before)], 'r--', label="No Change Line")
    plt.xlabel("Before")
    plt.ylabel("After")
    plt.title("Paired Sample Comparison")
    plt.legend()
    plt.show()

np.random.seed(42)
before = np.random.normal(loc=50, scale=5, size=30)
after = before + np.random.normal(loc=2, scale=3, size=30)
alpha = 0.05

test_result = paired_t_test(before, after, alpha)
print(test_result)

visualize_paired_t_test(before, after)
# Out:
# {'T-statistic': -3.208938334226974, 'p-value': 0.0032434967924499154, 'Decision': 'Reject the null hypothesis'}

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, ttest_rel, norm

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05):

    sample_size = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(abs(z_score)))
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"Z-score": z_score, "p-value": p_value, "Decision": interpretation}

def independent_t_test(sample1, sample2, alpha=0.05):

    t_stat, p_value = ttest_ind(sample1, sample2)
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"T-statistic": t_stat, "p-value": p_value, "Decision": interpretation}

def paired_t_test(before, after, alpha=0.05):

    t_stat, p_value = ttest_rel(before, after)
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"T-statistic": t_stat, "p-value": p_value, "Decision": interpretation}

def visualize_distributions(sample1, sample2):

    plt.figure(figsize=(10, 5))
    plt.hist(sample1, bins=15, alpha=0.5, label="Sample 1", density=True, color='blue')
    plt.hist(sample2, bins=15, alpha=0.5, label="Sample 2", density=True, color='green')
    plt.axvline(np.mean(sample1), color='blue', linestyle='dashed', label=f'Mean Sample 1 ({np.mean(sample1):.2f})')
    plt.axvline(np.mean(sample2), color='green', linestyle='dashed', label=f'Mean Sample 2 ({np.mean(sample2):.2f})')
    plt.title("Comparison of Sample Distributions")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.show()

np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=5, size=30)
sample2 = np.random.normal(loc=53, scale=5, size=30)
paired_before = np.random.normal(loc=50, scale=5, size=30)
paired_after = paired_before + np.random.normal(loc=2, scale=3, size=30)

alpha = 0.05
population_mean = 50
population_std = 5

z_test_result = one_sample_z_test(sample1, population_mean, population_std, alpha)
print("One-Sample Z-test Result:", z_test_result)

t_test_result = independent_t_test(sample1, sample2, alpha)
print("Independent T-test Result:", t_test_result)

paired_test_result = paired_t_test(paired_before, paired_after, alpha)
print("Paired Sample T-test Result:", paired_test_result)

visualize_distributions(sample1, sample2)
# Out:
# One-Sample Z-test Result: {'Z-score': -1.0305229898218877, 'p-value': 0.3027645658813305, 'Decision': 'Fail to reject the null hypothesis'}
# Independent T-test Result: {'T-statistic': -2.821074768517716, 'p-value': 0.006542565964576734, 'Decision': 'Reject the null hypothesis'}
# Paired Sample T-test Result: {'T-statistic': -3.8957698123011206, 'p-value': 0.0005305484606763112, 'Decision': 'Reject the null hypothesis'}

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, ttest_rel, norm, t

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05):

    sample_size = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(abs(z_score)))
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"Z-score": z_score, "p-value": p_value, "Decision": interpretation}

def independent_t_test(sample1, sample2, alpha=0.05):

    t_stat, p_value = ttest_ind(sample1, sample2)
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"T-statistic": t_stat, "p-value": p_value, "Decision": interpretation}

def paired_t_test(before, after, alpha=0.05):

    t_stat, p_value = ttest_rel(before, after)
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"T-statistic": t_stat, "p-value": p_value, "Decision": interpretation}

def confidence_interval(sample, confidence=0.95):

    sample_size = len(sample)
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    t_critical = t.ppf((1 + confidence) / 2, df=sample_size - 1)
    margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))
    return (sample_mean - margin_of_error, sample_mean + margin_of_error)

def visualize_distributions(sample1, sample2):

    plt.figure(figsize=(10, 5))
    plt.hist(sample1, bins=15, alpha=0.5, label="Sample 1", density=True, color='blue')
    plt.hist(sample2, bins=15, alpha=0.5, label="Sample 2", density=True, color='green')
    plt.axvline(np.mean(sample1), color='blue', linestyle='dashed', label=f'Mean Sample 1 ({np.mean(sample1):.2f})')
    plt.axvline(np.mean(sample2), color='green', linestyle='dashed', label=f'Mean Sample 2 ({np.mean(sample2):.2f})')
    plt.title("Comparison of Sample Distributions")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.show()

np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=5, size=30)
sample2 = np.random.normal(loc=53, scale=5, size=30)
paired_before = np.random.normal(loc=50, scale=5, size=30)
paired_after = paired_before + np.random.normal(loc=2, scale=3, size=30)

alpha = 0.05
population_mean = 50
population_std = 5

z_test_result = one_sample_z_test(sample1, population_mean, population_std, alpha)
print("One-Sample Z-test Result:", z_test_result)

t_test_result = independent_t_test(sample1, sample2, alpha)
print("Independent T-test Result:", t_test_result)

paired_test_result = paired_t_test(paired_before, paired_after, alpha)
print("Paired Sample T-test Result:", paired_test_result)

ci = confidence_interval(sample1)
print(f"Confidence Interval for Sample 1 Mean: {ci}")

visualize_distributions(sample1, sample2)
# Out:
# One-Sample Z-test Result: {'Z-score': -1.0305229898218877, 'p-value': 0.3027645658813305, 'Decision': 'Fail to reject the null hypothesis'}
# Independent T-test Result: {'T-statistic': -2.821074768517716, 'p-value': 0.006542565964576734, 'Decision': 'Reject the null hypothesis'}
# Paired Sample T-test Result: {'T-statistic': -3.8957698123011206, 'p-value': 0.0005305484606763112, 'Decision': 'Reject the null hypothesis'}
# Confidence Interval for Sample 1 Mean: (47.37892590517584, 50.73960513631378)

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, ttest_rel, norm, t

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05):
    """
    Perform a one-sample Z-test to compare the sample mean with the population mean.
    """
    sample_size = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(abs(z_score)))
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"Z-score": z_score, "p-value": p_value, "Decision": interpretation}

def independent_t_test(sample1, sample2, alpha=0.05):
    """
    Perform an independent T-test to compare the means of two samples.
    """
    t_stat, p_value = ttest_ind(sample1, sample2)
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"T-statistic": t_stat, "p-value": p_value, "Decision": interpretation}

def paired_t_test(before, after, alpha=0.05):
    """
    Perform a paired sample T-test to compare two related samples.
    """
    t_stat, p_value = ttest_rel(before, after)
    interpretation = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"
    return {"T-statistic": t_stat, "p-value": p_value, "Decision": interpretation}

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_size = len(sample)
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    t_critical = t.ppf((1 + confidence) / 2, df=sample_size - 1)
    margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))
    return (sample_mean - margin_of_error, sample_mean + margin_of_error)

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.
    """
    sample_size = len(sample)
    sample_std = np.std(sample, ddof=1)
    t_critical = t.ppf((1 + confidence) / 2, df=sample_size - 1)
    return t_critical * (sample_std / np.sqrt(sample_size))

def visualize_distributions(sample1, sample2):
    """
    Visualizes the distribution of two samples.
    """
    plt.figure(figsize=(10, 5))
    plt.hist(sample1, bins=15, alpha=0.5, label="Sample 1", density=True, color='blue')
    plt.hist(sample2, bins=15, alpha=0.5, label="Sample 2", density=True, color='green')
    plt.axvline(np.mean(sample1), color='blue', linestyle='dashed', label=f'Mean Sample 1 ({np.mean(sample1):.2f})')
    plt.axvline(np.mean(sample2), color='green', linestyle='dashed', label=f'Mean Sample 2 ({np.mean(sample2):.2f})')
    plt.title("Comparison of Sample Distributions")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.show()

# Simulate random sample data
np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=5, size=30)
sample2 = np.random.normal(loc=53, scale=5, size=30)
paired_before = np.random.normal(loc=50, scale=5, size=30)
paired_after = paired_before + np.random.normal(loc=2, scale=3, size=30)

alpha = 0.05
population_mean = 50
population_std = 5

# Perform Z-test
z_test_result = one_sample_z_test(sample1, population_mean, population_std, alpha)
print("One-Sample Z-test Result:", z_test_result)

# Perform independent T-test
t_test_result = independent_t_test(sample1, sample2, alpha)
print("Independent T-test Result:", t_test_result)

# Perform paired T-test
paired_test_result = paired_t_test(paired_before, paired_after, alpha)
print("Paired Sample T-test Result:", paired_test_result)

# Calculate confidence interval
ci = confidence_interval(sample1)
print(f"Confidence Interval for Sample 1 Mean: {ci}")

# Calculate margin of error
moe = margin_of_error(sample1)
print(f"Margin of Error for Sample 1 Mean: {moe:.4f}")

# Visualize distributions
visualize_distributions(sample1, sample2)
# Out:
# One-Sample Z-test Result: {'Z-score': -1.0305229898218877, 'p-value': 0.3027645658813305, 'Decision': 'Fail to reject the null hypothesis'}
# Independent T-test Result: {'T-statistic': -2.821074768517716, 'p-value': 0.006542565964576734, 'Decision': 'Reject the null hypothesis'}
# Paired Sample T-test Result: {'T-statistic': -3.8957698123011206, 'p-value': 0.0005305484606763112, 'Decision': 'Reject the null hypothesis'}
# Confidence Interval for Sample 1 Mean: (47.37892590517584, 50.73960513631378)
# Margin of Error for Sample 1 Mean: 1.6803

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.


P_D = 0.01
P_not_D = 1 - P_D

P_T_given_D = 0.95

P_T_given_not_D = 0.05
P_T = P_T_given_D * P_D + P_T_given_not_D * P_not_D

P_D_given_T = (P_T_given_D * P_D) / P_T

print(f"The probability that the person has the disease given a positive test result is: {P_D_given_T:.4f}")
# Out:
# The probability that the person has the disease given a positive test result is: 0.1610

# %%
#12. Perform a Chi-square test for independence between two categorical variables in Python.

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

data = {
    'Product A': [30, 10],  # 30 males and 10 females prefer Product A
    'Product B': [20, 40],  # 20 males and 40 females prefer Product B
}

df = pd.DataFrame(data, index=['Male', 'Female'])
print("Contingency Table:")
print(df)

chi2, p, dof, expected = chi2_contingency(df)

print(f"\nChi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies table:")
print(expected)

if p < 0.05:
    print("\nSince the p-value is less than 0.05, we reject the null hypothesis.")
    print("The variables are dependent.")
else:
    print("\nSince the p-value is greater than 0.05, we fail to reject the null hypothesis.")
    print("The variables are independent.")
# Out:
# Contingency Table:
#         Product A  Product B
# Male           30         20
# Female         10         40
#
# Chi-square statistic: 15.041666666666668
# P-value: 0.00010516355403363114
# Degrees of freedom: 1
# Expected frequencies table:
# [[20. 30.]
#  [20. 30.]]
#
# Since the p-value is less than 0.05, we reject the null hypothesis.
# The variables are dependent.

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

import numpy as np

observed = np.array([[30, 20],
                     [10, 40]])

row_totals = observed.sum(axis=1)
column_totals = observed.sum(axis=0)
grand_total = observed.sum()

expected = np.outer(row_totals, column_totals) / grand_total

print("Observed Frequencies:")
print(observed)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Observed Frequencies:
# [[30 20]
#  [10 40]]
#
# Expected Frequencies:
# [[20. 30.]
#  [20. 30.]]

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distributionD

import numpy as np
from scipy.stats import chisquare

observed = np.array([12, 10, 11, 9, 8, 10])

total_rolls = observed.sum()
expected = np.array([total_rolls / 6] * 6)

chi2_stat, p_value = chisquare(observed, expected)

print(f"Chi-square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("\nSince the p-value is less than 0.05, we reject the null hypothesis.")
    print("The observed data does not fit the expected distribution.")
else:
    print("\nSince the p-value is greater than 0.05, we fail to reject the null hypothesis.")
    print("The observed data fits the expected distribution.")
# Out:
# Chi-square Statistic: 1.0
# P-value: 0.9625657732472964
#
# Since the p-value is greater than 0.05, we fail to reject the null hypothesis.
# The observed data fits the expected distribution.

# %%
#15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

import numpy as np
import matplotlib.pyplot as plt

degrees_of_freedom = [1, 2, 5, 10, 20]
samples = {}
for df in degrees_of_freedom:
    samples[df] = np.random.chisquare(df, 1000)

plt.figure(figsize=(10, 6))
for df in degrees_of_freedom:
    plt.hist(samples[df], bins=30, alpha=0.5, label=f'df={df}', density=True)

plt.title('Chi-Square Distribution for Different Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
#16.  Implement an F-test using Python to compare the variances of two random samples.

import numpy as np
from scipy.stats import f

np.random.seed(0)
sample1 = np.random.normal(loc=50, scale=10, size=100)
sample2 = np.random.normal(loc=50, scale=20, size=100)

var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

F_statistic = var1 / var2 if var1 > var2 else var2 / var1

df1 = len(sample1) - 1
df2 = len(sample2) - 1

p_value = 1 - f.cdf(F_statistic, df1, df2)

print(f"Variance of Sample 1: {var1}")
print(f"Variance of Sample 2: {var2}")
print(f"F-statistic: {F_statistic}")
print(f"P-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    print("\nSince the p-value is less than 0.05, we reject the null hypothesis.")
    print("The variances of the two samples are significantly different.")
else:
    print("\nSince the p-value is greater than 0.05, we fail to reject the null hypothesis.")
    print("There is no significant difference between the variances of the two samples.")
# Out:
# Variance of Sample 1: 102.60874941564963
# Variance of Sample 2: 432.53971538918825
# F-statistic: 4.215427220899531
# P-value: 3.3513192221334975e-12
#
# Since the p-value is less than 0.05, we reject the null hypothesis.
# The variances of the two samples are significantly different.

# %%
#17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.

import numpy as np
from scipy.stats import f_oneway

group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=12, size=30)
group3 = np.random.normal(loc=60, scale=15, size=30)

f_statistic, p_value = f_oneway(group1, group2, group3)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    print("\nSince the p-value is less than 0.05, we reject the null hypothesis.")
    print("There is a significant difference between the group means.")
else:
    print("\nSince the p-value is greater than 0.05, we fail to reject the null hypothesis.")
    print("There is no significant difference between the group means.")
# Out:
# F-statistic: 5.795704618706158
# P-value: 0.004335984840423082
#
# Since the p-value is less than 0.05, we reject the null hypothesis.
# There is a significant difference between the group means.

# %%
#18.  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=12, size=30)
group3 = np.random.normal(loc=60, scale=15, size=30)

f_statistic, p_value = f_oneway(group1, group2, group3)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")

plt.figure(figsize=(8, 6))
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])
plt.title('Boxplot of Group Distributions')
plt.xlabel('Groups')
plt.ylabel('Values')
plt.grid(True)
plt.show()

alpha = 0.05
if p_value < alpha:
    print("\nSince the p-value is less than 0.05, we reject the null hypothesis.")
    print("There is a significant difference between the group means.")
else:
    print("\nSince the p-value is greater than 0.05, we fail to reject the null hypothesis.")
    print("There is no significant difference between the group means.")
# Out:
# F-statistic: 7.704273918844895
# P-value: 0.000830734883725171
# <ipython-input-22-2c352ffed9d3>:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])
# Since the p-value is less than 0.05, we reject the null hypothesis.
# There is a significant difference between the group means.

# %%
#19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, levene, probplot

def check_anova_assumptions(groups):
    print("Checking Normality (Shapiro-Wilk test):")
    for i, group in enumerate(groups):
        stat, p_value = shapiro(group)
        print(f"Group {i+1} - Shapiro-Wilk Test p-value: {p_value:.4f}")
        if p_value < 0.05:
            print(f"  Group {i+1} does NOT follow a normal distribution (p < 0.05).\n")
        else:
            print(f"  Group {i+1} follows a normal distribution (p >= 0.05).\n")

    print("Checking Equal Variance (Levene's test):")
    stat, p_value = levene(*groups)
    print(f"Levene's test p-value: {p_value:.4f}")
    if p_value < 0.05:
        print("  The variances are significantly different (p < 0.05).\n")
    else:
        print("  The variances are equal (p >= 0.05).\n")

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title('Boxplot of Groups')
    plt.xlabel('Groups')
    plt.ylabel('Values')

    plt.subplot(1, 2, 2)
    for i, group in enumerate(groups):
        probplot(group, dist="norm", plot=plt)
        plt.title(f'Q-Q Plot of Group {i+1}')
        plt.show()

np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=12, size=30)
group3 = np.random.normal(loc=60, scale=15, size=30)

check_anova_assumptions([group1, group2, group3])
# Out:
# Checking Normality (Shapiro-Wilk test):
# Group 1 - Shapiro-Wilk Test p-value: 0.6868
#   Group 1 follows a normal distribution (p >= 0.05).
#
# Group 2 - Shapiro-Wilk Test p-value: 0.9130
#   Group 2 follows a normal distribution (p >= 0.05).
#
# Group 3 - Shapiro-Wilk Test p-value: 0.3654
#   Group 3 follows a normal distribution (p >= 0.05).
#
# Checking Equal Variance (Levene's test):
# Levene's test p-value: 0.0620
#   The variances are equal (p >= 0.05).
# <ipython-input-23-e8235f77547a>:34: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])

# %%
#20.  Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.

import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import f

import matplotlib.pyplot as plt
import seaborn as sns

# Simulating data for two-way ANOVA
np.random.seed(42)

# Factor A (2 levels)
factor_a = ['A1', 'A2'] * 30  # 2 levels, 30 samples per level

# Factor B (3 levels)
factor_b = ['B1', 'B2', 'B3'] * 20  # 3 levels, 20 samples per level

# Dependent variable (DV)
# Random values from normal distribution for each combination of factor levels
dependent_variable = np.random.normal(loc=50, scale=10, size=60)

# Create a DataFrame
data = pd.DataFrame({
    'Factor_A': factor_a,
    'Factor_B': factor_b,
    'Dependent_Variable': dependent_variable
})

# Perform Two-Way ANOVA
model = ols('Dependent_Variable ~ Factor_A * Factor_B', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)  # Type II ANOVA table
print(anova_table)

# Visualize the interaction using an interaction plot
plt.figure(figsize=(10, 6))
sns.interactionplot(x=data['Factor_A'], y=data['Dependent_Variable'],
                    hue=data['Factor_B'], markers=['o', 's', 'D'], linestyles=['-', '--', ':'])
plt.title('Interaction Plot between Factor A and Factor B')
plt.xlabel('Factor A')
plt.ylabel('Dependent Variable')
plt.show()
# Out:
#                         sum_sq    df         F    PR(>F)
# Factor_A              0.661767   1.0  0.007769  0.930091
# Factor_B            132.629126   2.0  0.778497  0.464179
# Factor_A:Factor_B   136.762584   2.0  0.802760  0.453365
# Residual           4599.869222  54.0       NaN       NaN
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-214c8be7e53e> in <cell line: 0>()
#      37 # Visualize the interaction using an interaction plot
#      38 plt.figure(figsize=(10, 6))
# ---> 39 sns.interactionplot(x=data['Factor_A'], y=data['Dependent_Variable'],
#      40                     hue=data['Factor_B'], markers=['o', 's', 'D'], linestyles=['-', '--', ':'])
#      41 plt.title('Interaction Plot between Factor A and Factor B')
#
# AttributeError: module 'seaborn' has no attribute 'interactionplot'

# %%
#21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

dof_numerators = [2, 5, 10]
dof_denominators = [5, 10, 15]

x = np.linspace(0, 5, 1000)

plt.figure(figsize=(10, 6))
for dof_num in dof_numerators:
    for dof_den in dof_denominators:
        pdf_values = f.pdf(x, dfn=dof_num, dfd=dof_den)
        plt.plot(x, pdf_values, label=f'F({dof_num}, {dof_den})')

plt.title('F-distribution for Different Degrees of Freedom', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.legend(title="Degrees of Freedom", loc="upper right")
plt.grid(True)
plt.show()

# %%
#22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=15, size=30)
group3 = np.random.normal(loc=60, scale=20, size=30)

f_stat, p_value = stats.f_oneway(group1, group2, group3)

print(f"ANOVA F-statistic: {f_stat:.4f}")
print(f"ANOVA p-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: At least one group mean is different.")
else:
    print("Fail to reject the null hypothesis: The group means are equal.")

plt.figure(figsize=(10, 6))
sns.boxplot(data=[group1, group2, group3], showmeans=True,
            boxprops=dict(facecolor="lightblue", color="black"),
            flierprops=dict(marker='o', markerfacecolor='red', markersize=8, linestyle='none'))
plt.xticks([0, 1, 2], ['Group 1', 'Group 2', 'Group 3'])
plt.title("Boxplot of Group Means with One-Way ANOVA")
plt.ylabel("Values")
plt.xlabel("Groups")
plt.grid(True)
plt.show()
# Out:
# ANOVA F-statistic: 4.9963
# ANOVA p-value: 0.0088
# Reject the null hypothesis: At least one group mean is different.
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)

# %%
#23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

import numpy as np
import scipy.stats as stats

np.random.seed(42)

group1 = np.random.normal(loc=50, scale=10, size=30)

group2 = np.random.normal(loc=55, scale=15, size=30)

t_stat, p_value = stats.ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: The means of the two groups are significantly different.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the group means.")
# Out:
# T-statistic: -1.6694
# P-value: 0.1004
# Fail to reject the null hypothesis: There is no significant difference between the group means.

# %%
#24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the resultsD.

import numpy as np
import scipy.stats as stats

np.random.seed(42)

sample_data = np.random.normal(loc=50, scale=10, size=30)

sigma_squared_0 = 100

sample_variance = np.var(sample_data, ddof=1)

n = len(sample_data)

chi_square_stat = (n - 1) * sample_variance / sigma_squared_0

df = n - 1

p_value = 2 * min(stats.chi2.cdf(chi_square_stat, df), 1 - stats.chi2.cdf(chi_square_stat, df))

print(f"Chi-square Statistic: {chi_square_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: The population variance is significantly different from the hypothesized variance.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the sample variance and the hypothesized variance.")
# Out:
# Chi-square Statistic: 23.4903
# P-value: 0.4927
# Fail to reject the null hypothesis: There is no significant difference between the sample variance and the hypothesized variance.

# %%
#25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

import numpy as np
import scipy.stats as stats

x1 = 80
n1 = 100

x2 = 90
n2 = 120

p1 = x1 / n1
p2 = x2 / n2

P = (x1 + x2) / (n1 + n2)

z_stat = (p1 - p2) / np.sqrt(P * (1 - P) * (1 / n1 + 1 / n2))

p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: The proportions are significantly different.")
else:
    print("Fail to reject the null hypothesis: The proportions are not significantly different.")
# Out:
# Z-statistic: 0.8812
# P-value: 0.3782
# Fail to reject the null hypothesis: The proportions are not significantly different.

# %%
#26.  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

np.random.seed(42)

group1 = np.random.normal(loc=50, scale=10, size=30)

group2 = np.random.normal(loc=50, scale=15, size=30)

var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

F_stat = var1 / var2 if var1 > var2 else var2 / var1

df1 = len(group1) - 1
df2 = len(group2) - 1

p_value = 2 * min(stats.f.cdf(F_stat, df1, df2), 1 - stats.f.cdf(F_stat, df1, df2))

print(f"F-statistic: {F_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")

x = np.linspace(0, 5, 500)
y = stats.f.pdf(x, df1, df2)

plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})')
plt.axvline(x=F_stat, color='r', linestyle='--', label=f'F-statistic = {F_stat:.4f}')
plt.title('F-distribution and F-test Statistic')
plt.xlabel('F-statistic')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# F-statistic: 2.4082
# P-value: 0.0209
# Reject the null hypothesis: The variances are significantly different.

# %%
#27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

np.random.seed(42)

observed = np.random.choice([1, 2, 3, 4, 5, 6], size=100, replace=True)
observed_freq = np.array([np.sum(observed == i) for i in range(1, 7)])

expected_freq = np.array([100 / 6] * 6)

chi2_stat, p_value = stats.chisquare(observed_freq, expected_freq)

print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: The observed data does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data matches the expected distribution.")

categories = [1, 2, 3, 4, 5, 6]

plt.bar(categories, observed_freq, alpha=0.6, label='Observed', color='blue', width=0.4, align='center')
plt.bar(categories, expected_freq, alpha=0.6, label='Expected', color='red', width=0.4, align='edge')

plt.title('Chi-square Goodness of Fit Test')
plt.xlabel('Die Face')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Chi-square Statistic: 8.3600
# P-value: 0.1375
# Fail to reject the null hypothesis: The observed data matches the expected distribution.
